# %%
from Pump import AL1000

import serial
import time
from datetime import datetime
import re

#Defining ser_2
PORT3 = 'COM4'
ser = serial.Serial(port=PORT3, baudrate=9600, bytesize=8, parity='N', stopbits=1, timeout=2, xonxoff=False, rtscts=False)
pump = AL1000(ser)
pump.connect()
# Out:
# Device is connected

# %%
pump.command("ID")
# Out:
# Raw bytes: b'\xff\xff\xff'
# Sent: @00ID | Reply: ���
# '���'

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
from gilson_ethernet2 import GilsonSession
from rack import Rack, Rackcommands
from rack_setup_test import get_rack_setup, test_rack_positions
from rack_controller import go_to
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
g = GilsonSession("192.168.1.101")

# %%
rack, rack_commands = get_rack_setup()

# %%
g.home()
# Out:
# All axes homed successfully

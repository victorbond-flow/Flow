# %%
# %load_ext autoreload
# %autoreload 2

#import pandas as pd
from gilson_ethernet import GilsonSession

# %%
g = GilsonSession("192.168.1.101")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 g = GilsonSession("192.168.1.101")
#
# File ~\OneDrive - Queen's University Belfast\Desktop\code\VictorFlow\gilson_ethernet.py:17, in GilsonSession.__init__(self, ip, admin_port)
#      15 self.session_socket = None
#      16 self.sequence_number = 40
# ---> 17 self._connect()
#      18 self.send_admin_command()
#
# File ~\OneDrive - Queen's University Belfast\Desktop\code\VictorFlow\gilson_ethernet.py:26, in GilsonSession._connect(self)
#      24 with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
#      25     s.settimeout(5)
# ---> 26     s.connect((self.ip, self.admin_port))
#      27     s.sendall(message.encode('ascii'))
#      28     response = s.recv(4096).decode('ascii')
#
# TimeoutError: timed out

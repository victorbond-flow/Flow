# %%
import ftd2xx
print(ftd2xx.listDevices())
# Out:
# [b'']

# %%
import ftd2xx
import time

class Gilson4020PumpUSB:
    def __init__(self, ftdi_serial=b'G0SX4P41'):
        self.device = ftd2xx.openEx(ftdi_serial, 1)  # OPEN_BY_SERIAL_NUMBER = 1
        self.device.setTimeouts(1000, 1000)

    def send_command(self, command):
        self.device.write((command + "\r").encode('ascii'))
        time.sleep(0.2)
        response = self.device.read(1024)
        return response.decode('ascii', errors='ignore').strip()

    def identify(self):
        return self.send_command("Identify")

    def home(self):
        return self.send_command("Home")

    def close(self):
        self.device.close()

# %%
pump = Gilson4020PumpUSB()
print("Home:", pump.home())
print("Serial:", pump.send_command("Get Serial Number"))
pump.close()
# Out:
# ---------------------------------------------------------------------------
# DeviceError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pump = Gilson4020PumpUSB()
#       2 print("Home:", pump.home())
#       3 print("Serial:", pump.send_command("Get Serial Number"))
#
# Cell In[2], line 6, in Gilson4020PumpUSB.__init__(self, ftdi_serial)
#       5 def __init__(self, ftdi_serial=b'G0SX4P41'):
# ----> 6     self.device = ftd2xx.openEx(ftdi_serial, 1)  # OPEN_BY_SERIAL_NUMBER = 1
#       7     self.device.setTimeouts(1000, 1000)
#
# File ~\anaconda3\envs\gilson\Lib\site-packages\ftd2xx\ftd2xx.py:303, in openEx(id_str, flags, update)
#     282 """Open a handle to a usb device by serial number(default), description or
#     283 location(Windows only) depending on value of flags and return an FTD2XX
#     284 instance for it. Set update to False to avoid a slow call to createDeviceInfoList.
#    (...)    300
#     301 """
#     302 h = _ft.FT_HANDLE()
# --> 303 call_ft(_ft.FT_OpenEx, id_str, _ft.DWORD(flags), c.byref(h))
#     304 return FTD2XX(h, update=update)
#
# File ~\anaconda3\envs\gilson\Lib\site-packages\ftd2xx\ftd2xx.py:178, in call_ft(function, *args)
#     176 status = function(*args)
#     177 if status != defines.Status.OK:
# --> 178     raise DeviceError(status)
#
# DeviceError: DEVICE_NOT_OPENED

# %%
print("Home:", pump.send_command("Home"))
print("Serial:", pump.send_command("Get Serial Number"))
print("Firmware:", pump.send_command("Get Firmware Version"))
print("Syringe Info:", pump.send_command("Get Syringe Info"))
print("Motor Status:", pump.send_command("Get Motor Status"))

# %%
pump.close()

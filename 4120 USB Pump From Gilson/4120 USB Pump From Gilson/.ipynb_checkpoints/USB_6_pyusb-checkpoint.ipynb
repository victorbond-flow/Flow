# %% [markdown]
# Requires zadik driver - libusbK (v3.x.x)
#
# NEED TO TURN PUMP OFF AND ON AGAIN BEFORE TRYING AGAIN

# %%
import usb.core
import usb.util
import time

class Gilson4020USB:
    def __init__(self, vid=0x1FD0, pid=0x0404):
        self.dev = usb.core.find(idVendor=vid, idProduct=pid)
        if self.dev is None:
            raise ValueError("Gilson 4020 USB device not found.")

        self.dev.set_configuration()
        cfg = self.dev.get_active_configuration()
        self.interface_number = cfg[(0, 0)].bInterfaceNumber

        usb.util.claim_interface(self.dev, self.interface_number)
        print(f"Connected to Gilson 4020 on interface {self.interface_number}")

    def send_home_command(self):
        # Emulate the vendor-specific control transfer for 'Home'
        bmRequestType = 0x40  # Host to device, vendor, device
        bRequest = 3          # Vendor-defined command (matches Wireshark)
        wValue = 0xC068       # Matches value seen during HOME click
        wIndex = 0x0200       # Often used to specify report or channel

        print("[DEBUG] Sending HOME control transfer...")
        self.dev.ctrl_transfer(
            bmRequestType=bmRequestType,
            bRequest=bRequest,
            wValue=wValue,
            wIndex=wIndex,
            data_or_wLength=[]
        )
        print("[DEBUG] HOME command sent.")

    def release(self):
        usb.util.release_interface(self.dev, self.interface_number)
        usb.util.dispose_resources(self.dev)
        print("Released USB interface.")

# %%
pump = Gilson4020USB()
pump.send_home_command()
pump.release()
# Out:
# ---------------------------------------------------------------------------
# USBError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pump = Gilson4020USB()
#       2 pump.send_home_command()
#       3 pump.release()
#
# Cell In[1], line 11, in Gilson4020USB.__init__(self, vid, pid)
#       8 if self.dev is None:
#       9     raise ValueError("Gilson 4020 USB device not found.")
# ---> 11 self.dev.set_configuration()
#      12 cfg = self.dev.get_active_configuration()
#      13 self.interface_number = cfg[(0, 0)].bInterfaceNumber
#
# File ~\anaconda3\envs\gilson\Lib\site-packages\usb\core.py:929, in Device.set_configuration(self, configuration)
#     920 def set_configuration(self, configuration = None):
#     921     r"""Set the active configuration.
#     922
#     923     The configuration parameter is the bConfigurationValue field of the
#    (...)    927     without arguments is enough to get the device ready.
# ...

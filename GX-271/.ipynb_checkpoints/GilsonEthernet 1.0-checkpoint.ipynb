# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
from gilson_ethernet2 import GilsonSession
from rack_209 import Rack, Rackcommands

# --- Create the rack ---
rack = Rack()

# --- Connect Gilson + create rack commands ---
g = GilsonSession("192.168.1.101")

rack_cmds = Rackcommands(gilson_session=g, rack=rack)
rack_cmds.rack_home_x = rack_home_x
rack_cmds.rack_home_y = rack_home_y

# --- Z safety limits ---
g.Z_SAFE = rack.Z_SAFE          # Lower Z limit (mm)
g.Z_MAX_SAFE = rack.Z_MAX_SAFE     # Upper Z limit (mm)
g.Z_WORKING_MIN = self.Z_WORKING_MIN    # Lowest Z position allowed during vial operations (mm)

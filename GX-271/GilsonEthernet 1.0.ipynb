# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd

from gilson_ethernet2 import GilsonSession
from rack import Rack_209      #

# --- Connect to Gilson ---
g = GilsonSession("192.168.1.101", admin_port=50185)

# --- Add racks to the Gilson session ---
rack1 = Rack_209(g)
g.add_rack(rack1, rack_position=1)

# Optional: add more racks
# rack2 = AnotherRackType()
# g.add_rack(rack2, rack_position=2)
# Out:
# Rack 'Rack_209' added at position 1.

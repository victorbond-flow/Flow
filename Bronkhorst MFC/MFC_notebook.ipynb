# %% [markdown]
# # Imports and Setup
# This section imports PARAMS, which handles...(finish me)

# %%
import sys
sys.path.append('.')  # make sure Python can find MFC.py and parameters.py

from MFC import MFC
from parameters import PARAMS

# %%
#------------------------
# Connecting to device
#------------------------

mfc = MFC(port="zzzzz")  # <-- change COM, not plugged in yet
mfc.connect()

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd

from gilson_ethernet2 import GilsonSession
from rack import Rack_209      

# --- Connect to Gilson ---
g = GilsonSession("192.168.1.101", admin_port=50185)

# --- Add racks to the Gilson session ---
rack1 = Rack_209(g)
g.add_rack(rack1, rack_position=1)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
g.go_to_vial(16)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 g.go_to_vial(16)
#
# File ~\Documents\VictorFlow\GX_271\flow_logging.py:38, in FlowLogger.log_call.<locals>.wrapper(*args, **kwargs)
#      36 try:
#      37     self.logger.debug(f"CALL {func.__name__}({arg_str})")
# ---> 38     result = func(*args, **kwargs)
#      39     duration = time.time() - start_time
#      40     self.logger.debug(f"RETURN {func.__name__} -> {result!r} (Duration: {duration:.3f}s)")
#
# File ~\Documents\VictorFlow\GX_271\gilson_ethernet2.py:310, in GilsonSession.go_to_vial(self, vial_pos, rack_num)
#     307 @log_call
#     308 def go_to_vial(self, vial_pos, rack_num=1):
#     309     if rack_num not in self.racks:
# --> 310         raise ValueError(f"No rack at position {rack_num}")
#     311     return self.racks[rack_num].go_to_vial(vial_pos)
#
# ValueError: No rack at position 1
